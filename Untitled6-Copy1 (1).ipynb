# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller

# %%
data = pd.read_csv(r"C:\Users\santr\Downloads\airline_passengers.csv", parse_dates=['Month'],index_col='Month')

# %%
data
# Out:
#             Thousands of Passengers
# Month
# 1949-01-01                      112
# 1949-02-01                      118
# 1949-03-01                      132
# 1949-04-01                      129
# 1949-05-01                      121
# ...                             ...
# 1960-08-01                      606
# 1960-09-01                      508
# 1960-10-01                      461
# 1960-11-01                      390
# 1960-12-01                      432
#
# [144 rows x 1 columns]

# %%
result = seasonal_decompose(data, model='multiplicative')
result.plot()
plt.show()

# %%
plt.plot(data)
plt.xlabel('Month')
plt.ylabel('Thousands of Passengers')
plt.show()

# %%
adf_test = adfuller(data['Thousands of Passengers'])
print("ADF Test Statistic: ", adf_test[0])
print("p-value: ", adf_test[1])
# Out:
# ADF Test Statistic:  0.8153688792060463
# p-value:  0.991880243437641
